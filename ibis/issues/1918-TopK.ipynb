# %% [markdown]
# # BUG: TopK issues #1918
#
# - issue: https://github.com/ibis-project/ibis/issues/1918
# - doc: https://docs.ibis-project.org/sql.html?highlight=topk#top-k-operations

# %% [markdown]
# Problems

# %%
import os
from pathlib import Path 
import traceback

import ibis
import pandas as pd

# local settings
from settings import conf, data_directory, post_connection_spark

# %%
# data directory
assert os.path.exists(data_directory)
assert os.path.exists(data_directory / 'ibis_testing.db')

# connection settings
post_connection = dict(
    spark=post_connection_spark,
    pyspark= post_connection_spark
)

# %% [markdown]
# ## Check Top 3 operation

# %%
for backend_name in conf:
    print('\n#', '=' * 80)
    print('#', backend_name.center(80, '.'))
    print('#', '=' * 80)
    
    # connection
    con = getattr(ibis, backend_name).connect(**conf[backend_name])
    if backend_name in post_connection:
        post_connection[backend_name](con)
    
    alltypes = con.table('functional_alltypes')
    alltypes = alltypes.sort_by(alltypes.string_col)
    expr = alltypes.string_col.topk(3)
    try:
        print(expr.compile())
        display(expr.execute())
    except Exception as e:
        if isinstance(e, NotImplementedError):
            print('[II] NotImplementedError')
        else:
            print('[EE]', e)
# Out:
# # ================================================================================
# # ...................................omniscidb....................................
# # ================================================================================
# SELECT *
# FROM (
#   SELECT "string_col", count("string_col") AS "count"
#   FROM functional_alltypes
#   GROUP BY string_col
#   ORDER BY "string_col"
# ) t0
# ORDER BY "count" DESC
# LIMIT 3
#   string_col  count
# 0          6    730
# 1          2    730
# 2          0    730
# # ================================================================================
# # .....................................pandas.....................................
# # ================================================================================
# ref_0
# PandasTable[table]
#   name: functional_alltypes
#   schema:
#     index : int64
#     Unnamed: 0 : int64
#     id : int64
#     bool_col : boolean
#     tinyint_col : int64
#     smallint_col : int64
#     int_col : int64
#     bigint_col : int64
#     float_col : float64
#     double_col : float64
#     date_string_col : string
#     string_col : string
#     timestamp_col : timestamp
#     year : int64
#     month : int64
#
# ref_1
# Selection[table]
#   table:
#     Table: ref_0
#   sort_keys:
#     SortKey[array-sort]
#       expr:
#         string_col = Column[string*] 'string_col' from table
#           ref_0
#       ascending:
#         True
#
# TopK[topk]
#   string_col = Column[string*] 'string_col' from table
#     ref_1
#   k:
#     3
#   by:
#     count = Count[int64]
#       string_col = Column[string*] 'string_col' from table
#         ref_1
#       where:
#         None
# [II] NotImplementedError
#
# # ================================================================================
# # ......................................csv.......................................
# # ================================================================================
# ref_0
# CSVTable[table]
#   name: functional_alltypes
#   schema:
#     index : int64
#     Unnamed: 0 : int64
#     id : int64
#     bool_col : int64
#     tinyint_col : int64
#     smallint_col : int64
#     int_col : int64
#     bigint_col : int64
#     float_col : float64
#     double_col : float64
#     date_string_col : string
#     string_col : int64
#     timestamp_col : string
#     year : int64
#     month : int64
#
# ref_1
# Selection[table]
#   table:
#     Table: ref_0
#   sort_keys:
#     SortKey[array-sort]
#       expr:
#         string_col = Column[int64*] 'string_col' from table
#           ref_0
#       ascending:
#         True
#
# TopK[topk]
#   string_col = Column[int64*] 'string_col' from table
#     ref_1
#   k:
#     3
#   by:
#     count = Count[int64]
#       string_col = Column[int64*] 'string_col' from table
#         ref_1
#       where:
#         None
# [II] NotImplementedError
#
# # ================================================================================
# # ....................................parquet.....................................
# # ================================================================================
# ref_0
# ParquetTable[table]
#   name: functional_alltypes
#   schema:
#     index : int64
#     Unnamed: 0 : int64
#     id : int64
#     bool_col : boolean
#     tinyint_col : int8
#     smallint_col : int16
#     int_col : int32
#     bigint_col : int64
#     float_col : float32
#     double_col : float64
#     date_string_col : string
#     string_col : string
#     timestamp_col : timestamp
#     year : int64
#     month : int64
#
# ref_1
# Selection[table]
#   table:
#     Table: ref_0
#   sort_keys:
#     SortKey[array-sort]
#       expr:
#         string_col = Column[string*] 'string_col' from table
#           ref_0
#       ascending:
#         True
#
# TopK[topk]
#   string_col = Column[string*] 'string_col' from table
#     ref_1
#   k:
#     3
#   by:
#     count = Count[int64]
#       string_col = Column[string*] 'string_col' from table
#         ref_1
#       where:
#         None
# [II] NotImplementedError
#
# # ================================================================================
# # .....................................sqlite.....................................
# # ================================================================================
# SELECT t0.string_col, t0.count
# FROM (SELECT t1.string_col AS string_col, count(t1.string_col) AS count
# FROM base.functional_alltypes AS t1 GROUP BY t1.string_col ORDER BY t1.string_col) AS t0 ORDER BY t0.count DESC
#  LIMIT ? OFFSET ?
#   string_col  count
# 0          0    730
# 1          1    730
# 2          2    730
# # ================================================================================
# # ....................................postgres....................................
# # ================================================================================
# SELECT t0.string_col, t0.count
# FROM (SELECT t1.string_col AS string_col, count(t1.string_col) AS count
# FROM functional_alltypes AS t1 GROUP BY t1.string_col ORDER BY t1.string_col) AS t0 ORDER BY t0.count DESC
#  LIMIT %(param_1)s
#   string_col  count
# 0          1    730
# 1          2    730
# 2          0    730
# # ================================================================================
# # .....................................mysql......................................
# # ================================================================================
# SELECT t0.string_col, t0.count
# FROM (SELECT t1.string_col AS string_col, count(t1.string_col) AS count
# FROM functional_alltypes AS t1 GROUP BY t1.string_col ORDER BY t1.string_col) AS t0 ORDER BY t0.count DESC
#  LIMIT %(param_1)s
#   string_col  count
# 0          0    730
# 1          1    730
# 2          2    730
# # ================================================================================
# # ...................................clickhouse...................................
# # ================================================================================
# SELECT *
# FROM (
#   SELECT `string_col`, count(`string_col`) AS `count`
#   FROM ibis_testing.`functional_alltypes`
#   GROUP BY `string_col`
#   ORDER BY `string_col`
# ) t0
# ORDER BY `count` DESC
# LIMIT 3
#   string_col  count
# 0          0    730
# 1          1    730
# 2          2    730
# # ================================================================================
# # .....................................impala.....................................
# # ================================================================================
# SELECT *
# FROM (
#   SELECT `string_col`, count(`string_col`) AS `count`
#   FROM ibis_testing.`functional_alltypes`
#   GROUP BY 1
#   ORDER BY `string_col`
# ) t0
# ORDER BY `count` DESC
# LIMIT 3
#   string_col  count
# 0          3    730
# 1          1    730
# 2          4    730
# # ================================================================================
# # ....................................pyspark.....................................
# # ================================================================================
# [EE] No translation rule for <class 'ibis.expr.operations.TopK'>
#
# # ================================================================================
# # .....................................spark......................................
# # ================================================================================
# SELECT *
# FROM (
#   SELECT `string_col`, count(`string_col`) AS `count`
#   FROM functional_alltypes
#   GROUP BY 1
#   ORDER BY `string_col`
# ) t0
# ORDER BY `count` DESC
# LIMIT 3
#   string_col  count
# 0          0    730
# 1          3    730
# 2          8    730

# %% [markdown]
# ## Check Top 3 operation as table filter

# %%
# case 1: SQLite
con = ibis.sqlite.connect(str(data_directory / 'ibis_testing.db'))

alltypes = con.table('functional_alltypes')
alltypes = alltypes.sort_by(alltypes.string_col)
expr = alltypes[alltypes.string_col.topk(3)]

print('>', expr.compile())
# high time / memory consumption
# display(expr.execute())
# Out:
# > SELECT t0."index", t0."Unnamed: 0", t0.id, t0.bool_col, t0.tinyint_col, t0.smallint_col, t0.int_col, t0.bigint_col, t0.float_col, t0.double_col, t0.date_string_col, t0.string_col, t0.timestamp_col, t0.year, t0.month
# FROM (SELECT t2."index" AS "index", t2."Unnamed: 0" AS "Unnamed: 0", t2.id AS id, t2.bool_col AS bool_col, t2.tinyint_col AS tinyint_col, t2.smallint_col AS smallint_col, t2.int_col AS int_col, t2.bigint_col AS bigint_col, t2.float_col AS float_col, t2.double_col AS double_col, t2.date_string_col AS date_string_col, t2.string_col AS string_col, t2.timestamp_col AS timestamp_col, t2.year AS year, t2.month AS month
# FROM base.functional_alltypes AS t2 ORDER BY t2.string_col) AS t0, (SELECT t0."index" AS "index", t0."Unnamed: 0" AS "Unnamed: 0", t0.id AS id, t0.bool_col AS bool_col, t0.tinyint_col AS tinyint_col, t0.smallint_col AS smallint_col, t0.int_col AS int_col, t0.bigint_col AS bigint_col, t0.float_col AS float_col, t0.double_col AS double_col, t0.date_string_col AS date_string_col, t0.string_col AS string_col, t0.timestamp_col AS timestamp_col, t0.year AS year, t0.month AS month
# FROM (SELECT t2."index" AS "index", t2."Unnamed: 0" AS "Unnamed: 0", t2.id AS id, t2.bool_col AS bool_col, t2.tinyint_col AS tinyint_col, t2.smallint_col AS smallint_col, t2.int_col AS int_col, t2.bigint_col AS bigint_col, t2.float_col AS float_col, t2.double_col AS double_col, t2.date_string_col AS date_string_col, t2.string_col AS string_col, t2.timestamp_col AS timestamp_col, t2.year AS year, t2.month AS month
# FROM base.functional_alltypes AS t2 ORDER BY t2.string_col) AS t0
# WHERE EXISTS (SELECT 1
# FROM (SELECT t2.string_col AS string_col, t2.count AS count
# FROM (SELECT t3.string_col AS string_col, count(t3.string_col) AS count
# FROM base.functional_alltypes AS t3 GROUP BY t3.string_col ORDER BY t3.string_col) AS t2 ORDER BY t2.count DESC
#  LIMIT ? OFFSET ?) AS t1
# WHERE t0.string_col = t1.string_col))

# %%
for backend_name in set(conf.keys()) - {'sqlite'}:
    print('\n#', '=' * 80)
    print('#', backend_name.center(80, '.'))
    print('#', '=' * 80)
    
    # connection
    con = getattr(ibis, backend_name).connect(**conf[backend_name])
    if backend_name in post_connection:
        post_connection[backend_name](con)
    
    alltypes = con.table('functional_alltypes')
    expr = alltypes[alltypes.string_col.topk(3)]
    
    try:
        print('>', expr.compile())
        display(expr.execute())
    except Exception as e:
        if isinstance(e, NotImplementedError):
            print('[II] NotImplementedError')
        else:
            print('[EE]', traceback.format_exc())
# Out:
# # ================================================================================
# # ...................................clickhouse...................................
# # ================================================================================
# [EE] Traceback (most recent call last):
#   File "<ipython-input-5-24e49116336e>", line 15, in <module>
#     print('>', expr.compile())
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/expr/types.py", line 215, in compile
#     return compile(self, limit=limit, params=params)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 370, in compile
#     return backend.compile(expr, limit=limit, params=params, **kwargs)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 233, in compile
#     return query_ast.compile()
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/sql/compiler.py", line 54, in compile
#     compiled_queries = [q.compile() for q in self.queries]
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/sql/compiler.py", line 54, in <listcomp>
#     compiled_queries = [q.compile() for q in self.queries]
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/sql/compiler.py", line 1567, in compile
#     from_frag = self.format_table_set()
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/sql/compiler.py", line 1684, in format_table_set
#     fragment += helper.get_result()
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/clickhouse/compiler.py", line 109, in get_result
#     self._walk_join_tree(op)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/sql/compiler.py", line 1795, in _walk_join_tree
#     jname = self._get_join_type(op)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/sql/compiler.py", line 1836, in _get_join_type
#     return self._join_names[type(op)]
# KeyError: <class 'ibis.expr.operations.LeftSemiJoin'>
#
#
# # ================================================================================
# # .....................................spark......................................
# # ================================================================================
# > SELECT t0.*
# FROM functional_alltypes t0
#   LEFT SEMI JOIN (
#     SELECT *
#     FROM (
#       SELECT `string_col`, count(`string_col`) AS `count`
#       FROM functional_alltypes
#       GROUP BY 1
#     ) t2
#     ORDER BY `count` DESC
#     LIMIT 3
#   ) t1
#     ON t0.`string_col` = t1.`string_col`
#       index  Unnamed: 0    id  bool_col  tinyint_col  smallint_col  int_col  \
# 0         3           3  6693     False            3             3        3
# 1         7           7  6697     False            7             7        7
# 2         8           8  6698      True            8             8        8
# 3        13          13  6703     False            3             3        3
# 4        17          17  6707     False            7             7        7
# ...     ...         ...   ...       ...          ...           ...      ...
# 2185   7287        7287  3947     False            7             7        7
# 2186   7288        7288  3948      True            8             8        8
# 2187   7293        7293  3953     False            3             3        3
# 2188   7297        7297  3957     False            7             7        7
# 2189   7298        7298  3958      True            8             8        8
#
#       bigint_col  float_col  double_col date_string_col string_col  \
# 0             30        3.3        30.3        11/01/10          3
# 1             70        7.7        70.7        11/01/10          7
# 2             80        8.8        80.8        11/01/10          8
# 3             30        3.3        30.3        11/02/10          3
# 4             70        7.7        70.7        11/02/10          7
# ...          ...        ...         ...             ...        ...
# 2185          70        7.7        70.7        01/30/10          7
# 2186          80        8.8        80.8        01/30/10          8
# 2187          30        3.3        30.3        01/31/10          3
# 2188          70        7.7        70.7        01/31/10          7
# 2189          80        8.8        80.8        01/31/10          8
#
#                timestamp_col  year  month
# 0    2010-11-01 04:03:00.300  2010     11
# 1    2010-11-01 04:07:00.210  2010     11
# 2    2010-11-01 04:08:00.280  2010     11
# 3    2010-11-02 04:13:00.480  2010     11
# 4    2010-11-02 04:17:00.660  2010     11
# ...                      ...   ...    ...
# 2185 2010-01-30 08:57:13.260  2010      1
# 2186 2010-01-30 08:58:13.330  2010      1
# 2187 2010-01-31 09:03:13.530  2010      1
# 2188 2010-01-31 09:07:13.710  2010      1
# 2189 2010-01-31 09:08:13.780  2010      1
#
# [2190 rows x 15 columns]
# # ================================================================================
# # ....................................parquet.....................................
# # ================================================================================
# > ref_0
# ParquetTable[table]
#   name: functional_alltypes
#   schema:
#     index : int64
#     Unnamed: 0 : int64
#     id : int64
#     bool_col : boolean
#     tinyint_col : int8
#     smallint_col : int16
#     int_col : int32
#     bigint_col : int64
#     float_col : float32
#     double_col : float64
#     date_string_col : string
#     string_col : string
#     timestamp_col : timestamp
#     year : int64
#     month : int64
#
# Selection[table]
#   table:
#     Table: ref_0
#   predicates:
#     SummaryFilter[boolean*]
#       expr:
#         TopK[topk]
#           string_col = Column[string*] 'string_col' from table
#             ref_0
#           k:
#             3
#           by:
#             count = Count[int64]
#               string_col = Column[string*] 'string_col' from table
#                 ref_0
#               where:
#                 None
# [II] NotImplementedError
#
# # ================================================================================
# # ....................................postgres....................................
# # ================================================================================
# > SELECT t0.index, t0."Unnamed: 0", t0.id, t0.bool_col, t0.tinyint_col, t0.smallint_col, t0.int_col, t0.bigint_col, t0.float_col, t0.double_col, t0.date_string_col, t0.string_col, t0.timestamp_col, t0.year, t0.month
# FROM functional_alltypes AS t0, (SELECT t0.index AS index, t0."Unnamed: 0" AS "Unnamed: 0", t0.id AS id, t0.bool_col AS bool_col, t0.tinyint_col AS tinyint_col, t0.smallint_col AS smallint_col, t0.int_col AS int_col, t0.bigint_col AS bigint_col, t0.float_col AS float_col, t0.double_col AS double_col, t0.date_string_col AS date_string_col, t0.string_col AS string_col, t0.timestamp_col AS timestamp_col, t0.year AS year, t0.month AS month
# FROM functional_alltypes AS t0
# WHERE EXISTS (SELECT 1
# FROM (SELECT t2.string_col AS string_col, t2.count AS count
# FROM (SELECT t0.string_col AS string_col, count(t0.string_col) AS count
# FROM functional_alltypes AS t0 GROUP BY t0.string_col) AS t2 ORDER BY t2.count DESC
#  LIMIT %(param_1)s) AS t1
# WHERE t0.string_col = t1.string_col))
# [EE] Traceback (most recent call last):
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1246, in _execute_context
#     cursor, statement, parameters, context
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/default.py", line 588, in do_execute
#     cursor.execute(statement, parameters)
# psycopg2.errors.SyntaxError: subquery in FROM must have an alias
# LINE 2: FROM functional_alltypes AS t0, (SELECT t0.index AS index, t...
#                                         ^
# HINT:  For example, FROM (SELECT ...) [AS] foo.
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-5-24e49116336e>", line 16, in <module>
#     display(expr.execute())
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/expr/types.py", line 202, in execute
#     return execute(self, limit=limit, params=params, **kwargs)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 352, in execute
#     return backend.execute(expr, limit=limit, params=params, **kwargs)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 215, in execute
#     result = self._execute_query(query_ast, **kwargs)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 220, in _execute_query
#     return query.execute()
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 54, in execute
#     self.compiled_sql, results=True, **kwargs
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/sql/alchemy.py", line 1212, in _execute
#     return AlchemyProxy(self.con.execute(query))
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 2182, in execute
#     return connection.execute(statement, *multiparams, **params)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 982, in execute
#     return meth(self, multiparams, params)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 293, in _execute_on_connection
#     return connection._execute_clauseelement(self, multiparams, params)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1101, in _execute_clauseelement
#     distilled_params,
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1250, in _execute_context
#     e, statement, parameters, cursor, context
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1476, in _handle_dbapi_exception
#     util.raise_from_cause(sqlalchemy_exception, exc_info)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 398, in raise_from_cause
#     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 152, in reraise
#     raise value.with_traceback(tb)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1246, in _execute_context
#     cursor, statement, parameters, context
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/default.py", line 588, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.ProgrammingError: (psycopg2.errors.SyntaxError) subquery in FROM must have an alias
# LINE 2: FROM functional_alltypes AS t0, (SELECT t0.index AS index, t...
#                                         ^
# HINT:  For example, FROM (SELECT ...) [AS] foo.
#
# [SQL: SELECT t0.index, t0."Unnamed: 0", t0.id, t0.bool_col, t0.tinyint_col, t0.smallint_col, t0.int_col, t0.bigint_col, t0.float_col, t0.double_col, t0.date_string_col, t0.string_col, t0.timestamp_col, t0.year, t0.month
# FROM functional_alltypes AS t0, (SELECT t0.index AS index, t0."Unnamed: 0" AS "Unnamed: 0", t0.id AS id, t0.bool_col AS bool_col, t0.tinyint_col AS tinyint_col, t0.smallint_col AS smallint_col, t0.int_col AS int_col, t0.bigint_col AS bigint_col, t0.float_col AS float_col, t0.double_col AS double_col, t0.date_string_col AS date_string_col, t0.string_col AS string_col, t0.timestamp_col AS timestamp_col, t0.year AS year, t0.month AS month
# FROM functional_alltypes AS t0
# WHERE EXISTS (SELECT 1
# FROM (SELECT t2.string_col AS string_col, t2.count AS count
# FROM (SELECT t0.string_col AS string_col, count(t0.string_col) AS count
# FROM functional_alltypes AS t0 GROUP BY t0.string_col) AS t2 ORDER BY t2.count DESC
#  LIMIT %(param_1)s) AS t1
# WHERE t0.string_col = t1.string_col))]
# [parameters: {'param_1': 3}]
# (Background on this error at: http://sqlalche.me/e/f405)
#
#
# # ================================================================================
# # ....................................pyspark.....................................
# # ================================================================================
# [EE] Traceback (most recent call last):
#   File "<ipython-input-5-24e49116336e>", line 15, in <module>
#     print('>', expr.compile())
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/expr/types.py", line 215, in compile
#     return compile(self, limit=limit, params=params)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 370, in compile
#     return backend.compile(expr, limit=limit, params=params, **kwargs)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/pyspark/client.py", line 33, in compile
#     return self.translator.translate(expr, scope=scope)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/pyspark/compiler.py", line 65, in translate
#     result = formatter(self, expr, scope, **kwargs)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/pyspark/compiler.py", line 116, in compile_selection
#     col = t.translate(predicate, scope)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/pyspark/compiler.py", line 70, in translate
#     'No translation rule for {}'.format(type(op))
# ibis.common.exceptions.OperationNotDefinedError: No translation rule for <class 'ibis.expr.operations.SummaryFilter'>
#
#
# # ================================================================================
# # ......................................csv.......................................
# # ================================================================================
# > ref_0
# CSVTable[table]
#   name: functional_alltypes
#   schema:
#     index : int64
#     Unnamed: 0 : int64
#     id : int64
#     bool_col : int64
#     tinyint_col : int64
#     smallint_col : int64
#     int_col : int64
#     bigint_col : int64
#     float_col : float64
#     double_col : float64
#     date_string_col : string
#     string_col : int64
#     timestamp_col : string
#     year : int64
#     month : int64
#
# Selection[table]
#   table:
#     Table: ref_0
#   predicates:
#     SummaryFilter[boolean*]
#       expr:
#         TopK[topk]
#           string_col = Column[int64*] 'string_col' from table
#             ref_0
#           k:
#             3
#           by:
#             count = Count[int64]
#               string_col = Column[int64*] 'string_col' from table
#                 ref_0
#               where:
#                 None
# [II] NotImplementedError
#
# # ================================================================================
# # ...................................omniscidb....................................
# # ================================================================================
# > SELECT t0.*
# FROM functional_alltypes t0
#   JOIN (
#     SELECT *
#     FROM (
#       SELECT "string_col", count("string_col") AS "count"
#       FROM functional_alltypes
#       GROUP BY string_col
#     ) t2
#     ORDER BY "count" DESC
#     LIMIT 3
#   ) t1
#     ON t0."string_col" = t1."string_col"
#       index  Unnamed__0    id  bool_col  tinyint_col  smallint_col  int_col  \
# 0         0           0  6690      True            0             0        0
# 1         2           2  6692      True            2             2        2
# 2         6           6  6696      True            6             6        6
# 3        10          10  6700      True            0             0        0
# 4        12          12  6702      True            2             2        2
# ...     ...         ...   ...       ...          ...           ...      ...
# 2185   7282        7282  3942      True            2             2        2
# 2186   7286        7286  3946      True            6             6        6
# 2187   7290        7290  3950      True            0             0        0
# 2188   7292        7292  3952      True            2             2        2
# 2189   7296        7296  3956      True            6             6        6
#
#       bigint_col  float_col  double_col date_string_col string_col  \
# 0              0        0.0         0.0        11/01/10          0
# 1             20        2.2        20.2        11/01/10          2
# 2             60        6.6        60.6        11/01/10          6
# 3              0        0.0         0.0        11/02/10          0
# 4             20        2.2        20.2        11/02/10          2
# ...          ...        ...         ...             ...        ...
# 2185          20        2.2        20.2        01/30/10          2
# 2186          60        6.6        60.6        01/30/10          6
# 2187           0        0.0         0.0        01/31/10          0
# 2188          20        2.2        20.2        01/31/10          2
# 2189          60        6.6        60.6        01/31/10          6
#
#            timestamp_col  year_  month_  rowid
# 0    2010-11-01 00:00:00   2010      11      0
# 1    2010-11-01 00:02:00   2010      11      2
# 2    2010-11-01 00:06:00   2010      11      6
# 3    2010-11-02 00:10:00   2010      11     10
# 4    2010-11-02 00:12:00   2010      11     12
# ...                  ...    ...     ...    ...
# 2185 2010-01-30 04:52:13   2010       1   7282
# 2186 2010-01-30 04:56:13   2010       1   7286
# 2187 2010-01-31 05:00:13   2010       1   7290
# 2188 2010-01-31 05:02:13   2010       1   7292
# 2189 2010-01-31 05:06:13   2010       1   7296
#
# [2190 rows x 16 columns]
# # ================================================================================
# # .....................................mysql......................................
# # ================================================================================
# > SELECT t0.`index`, t0.`Unnamed: 0`, t0.id, t0.bool_col, t0.tinyint_col, t0.smallint_col, t0.int_col, t0.bigint_col, t0.float_col, t0.double_col, t0.date_string_col, t0.string_col, t0.timestamp_col, t0.year, t0.month
# FROM functional_alltypes AS t0, (SELECT t0.`index` AS `index`, t0.`Unnamed: 0` AS `Unnamed: 0`, t0.id AS id, t0.bool_col AS bool_col, t0.tinyint_col AS tinyint_col, t0.smallint_col AS smallint_col, t0.int_col AS int_col, t0.bigint_col AS bigint_col, t0.float_col AS float_col, t0.double_col AS double_col, t0.date_string_col AS date_string_col, t0.string_col AS string_col, t0.timestamp_col AS timestamp_col, t0.year AS year, t0.month AS month
# FROM functional_alltypes AS t0
# WHERE EXISTS (SELECT 1
# FROM (SELECT t2.string_col AS string_col, t2.count AS count
# FROM (SELECT t0.string_col AS string_col, count(t0.string_col) AS count
# FROM functional_alltypes AS t0 GROUP BY t0.string_col) AS t2 ORDER BY t2.count DESC
#  LIMIT %(param_1)s) AS t1
# WHERE t0.string_col = t1.string_col))
# [EE] Traceback (most recent call last):
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1246, in _execute_context
#     cursor, statement, parameters, context
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/default.py", line 588, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/cursors.py", line 170, in execute
#     result = self._query(query)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/cursors.py", line 328, in _query
#     conn.query(q)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/connections.py", line 517, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/connections.py", line 732, in _read_query_result
#     result.read()
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/connections.py", line 1075, in read
#     first_packet = self.connection._read_packet()
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/connections.py", line 684, in _read_packet
#     packet.check_error()
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/protocol.py", line 220, in check_error
#     err.raise_mysql_exception(self._data)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/err.py", line 109, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.InternalError: (1248, 'Every derived table must have its own alias')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-5-24e49116336e>", line 16, in <module>
#     display(expr.execute())
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/expr/types.py", line 202, in execute
#     return execute(self, limit=limit, params=params, **kwargs)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 352, in execute
#     return backend.execute(expr, limit=limit, params=params, **kwargs)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 215, in execute
#     result = self._execute_query(query_ast, **kwargs)
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 220, in _execute_query
#     return query.execute()
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/client.py", line 54, in execute
#     self.compiled_sql, results=True, **kwargs
#   File "/home/xmn/dev/quansight/ibis-project/ibis/ibis/sql/alchemy.py", line 1212, in _execute
#     return AlchemyProxy(self.con.execute(query))
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 2182, in execute
#     return connection.execute(statement, *multiparams, **params)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 982, in execute
#     return meth(self, multiparams, params)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/sql/elements.py", line 293, in _execute_on_connection
#     return connection._execute_clauseelement(self, multiparams, params)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1101, in _execute_clauseelement
#     distilled_params,
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1250, in _execute_context
#     e, statement, parameters, cursor, context
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1476, in _handle_dbapi_exception
#     util.raise_from_cause(sqlalchemy_exception, exc_info)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 398, in raise_from_cause
#     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/util/compat.py", line 152, in reraise
#     raise value.with_traceback(tb)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/base.py", line 1246, in _execute_context
#     cursor, statement, parameters, context
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/sqlalchemy/engine/default.py", line 588, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/cursors.py", line 170, in execute
#     result = self._query(query)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/cursors.py", line 328, in _query
#     conn.query(q)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/connections.py", line 517, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/connections.py", line 732, in _read_query_result
#     result.read()
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/connections.py", line 1075, in read
#     first_packet = self.connection._read_packet()
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/connections.py", line 684, in _read_packet
#     packet.check_error()
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/protocol.py", line 220, in check_error
#     err.raise_mysql_exception(self._data)
#   File "/home/xmn/miniconda3/envs/ibis-nb/lib/python3.7/site-packages/pymysql/err.py", line 109, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.InternalError: (pymysql.err.InternalError) (1248, 'Every derived table must have its own alias')
# [SQL: SELECT t0.`index`, t0.`Unnamed: 0`, t0.id, t0.bool_col, t0.tinyint_col, t0.smallint_col, t0.int_col, t0.bigint_col, t0.float_col, t0.double_col, t0.date_string_col, t0.string_col, t0.timestamp_col, t0.year, t0.month
# FROM functional_alltypes AS t0, (SELECT t0.`index` AS `index`, t0.`Unnamed: 0` AS `Unnamed: 0`, t0.id AS id, t0.bool_col AS bool_col, t0.tinyint_col AS tinyint_col, t0.smallint_col AS smallint_col, t0.int_col AS int_col, t0.bigint_col AS bigint_col, t0.float_col AS float_col, t0.double_col AS double_col, t0.date_string_col AS date_string_col, t0.string_col AS string_col, t0.timestamp_col AS timestamp_col, t0.year AS year, t0.month AS month
# FROM functional_alltypes AS t0
# WHERE EXISTS (SELECT 1
# FROM (SELECT t2.string_col AS string_col, t2.count AS count
# FROM (SELECT t0.string_col AS string_col, count(t0.string_col) AS count
# FROM functional_alltypes AS t0 GROUP BY t0.string_col) AS t2 ORDER BY t2.count DESC
#  LIMIT %(param_1)s) AS t1
# WHERE t0.string_col = t1.string_col))]
# [parameters: {'param_1': 3}]
# (Background on this error at: http://sqlalche.me/e/2j85)
#
#
# # ================================================================================
# # .....................................impala.....................................
# # ================================================================================
# > SELECT t0.*
# FROM ibis_testing.`functional_alltypes` t0
#   LEFT SEMI JOIN (
#     SELECT *
#     FROM (
#       SELECT `string_col`, count(`string_col`) AS `count`
#       FROM ibis_testing.`functional_alltypes`
#       GROUP BY 1
#     ) t2
#     ORDER BY `count` DESC
#     LIMIT 3
#   ) t1
#     ON t0.`string_col` = t1.`string_col`
#         id  bool_col  tinyint_col  smallint_col  int_col  bigint_col  \
# 0     5773     False            3             3        3          30
# 1     5776      True            6             6        6          60
# 2     5779     False            9             9        9          90
# 3     5783     False            3             3        3          30
# 4     5786      True            6             6        6          60
# ...    ...       ...          ...           ...      ...         ...
# 2185   576      True            6             6        6          60
# 2186   579     False            9             9        9          90
# 2187   583     False            3             3        3          30
# 2188   586      True            6             6        6          60
# 2189   589     False            9             9        9          90
#
#       float_col  double_col date_string_col string_col  \
# 0           3.3        30.3        08/01/10          3
# 1           6.6        60.6        08/01/10          6
# 2           9.9        90.9        08/01/10          9
# 3           3.3        30.3        08/02/10          3
# 4           6.6        60.6        08/02/10          6
# ...         ...         ...             ...        ...
# 2185        6.6        60.6        02/27/09          6
# 2186        9.9        90.9        02/27/09          9
# 2187        3.3        30.3        02/28/09          3
# 2188        6.6        60.6        02/28/09          6
# 2189        9.9        90.9        02/28/09          9
#
#                timestamp_col  year  month
# 0    2010-08-01 00:03:00.300  2010      8
# 1    2010-08-01 00:06:00.150  2010      8
# 2    2010-08-01 00:09:00.360  2010      8
# 3    2010-08-02 00:13:00.480  2010      8
# 4    2010-08-02 00:16:00.600  2010      8
# ...                      ...   ...    ...
# 2185 2009-02-27 04:26:11.850  2009      2
# 2186 2009-02-27 04:29:12.600  2009      2
# 2187 2009-02-28 04:33:12.180  2009      2
# 2188 2009-02-28 04:36:12.300  2009      2
# 2189 2009-02-28 04:39:12.510  2009      2
#
# [2190 rows x 13 columns]
# # ================================================================================
# # .....................................pandas.....................................
# # ================================================================================
# > ref_0
# PandasTable[table]
#   name: functional_alltypes
#   schema:
#     index : int64
#     Unnamed: 0 : int64
#     id : int64
#     bool_col : boolean
#     tinyint_col : int64
#     smallint_col : int64
#     int_col : int64
#     bigint_col : int64
#     float_col : float64
#     double_col : float64
#     date_string_col : string
#     string_col : string
#     timestamp_col : timestamp
#     year : int64
#     month : int64
#
# Selection[table]
#   table:
#     Table: ref_0
#   predicates:
#     SummaryFilter[boolean*]
#       expr:
#         TopK[topk]
#           string_col = Column[string*] 'string_col' from table
#             ref_0
#           k:
#             3
#           by:
#             count = Count[int64]
#               string_col = Column[string*] 'string_col' from table
#                 ref_0
#               where:
#                 None
# [II] NotImplementedError
