# %%
import ibis

# %%
'''
con = ibis.postgres.connect(
    host='localhost', user='user', password='pass',
    port=5432, database='dbname'
)
'''

# %%
ibis.options.interactive = False
ibis.options.sql.default_limit = 100
ibis.options.verbose = False

# %%
t = ibis.table(
    [('one', 'string'),
     ('two', 'double'),
     ('three', 'int32')], 'my_data')

# %%
t
# Out:
# UnboundTable[table]
#   name: my_data
#   schema:
#     one : string
#     two : double
#     three : int32

# %%
proj = t['two', 'one']

# %%
proj
# Out:
# ref_0
# UnboundTable[table]
#   name: my_data
#   schema:
#     one : string
#     two : double
#     three : int32
#
# Selection[table]
#   table:
#     Table: ref_0
#   selections:
#     two = Column[double*] 'two' from table
#       ref_0
#     one = Column[string*] 'one' from table
#       ref_0

# %%
print(ibis.postgres.compile(proj))
# Out:
# SELECT t0.two, t0.one
# FROM my_data AS t0

# %%
new_col = (t.three * 2).name('new_col')
proj = t['two', 'one', new_col]
print(ibis.impala.compile(proj))
# Out:
# SELECT `two`, `one`, `three` * 2 AS `new_col`
# FROM my_data

# %%
mutated = t.mutate(new_col=t.three * 2)
print(ibis.impala.compile(mutated))
# Out:
# SELECT *, `three` * 2 AS `new_col`
# FROM my_data

# %%
mutated = t.mutate(two=t.two * 2)
print(ibis.impala.compile(mutated))
# Out:
# SELECT `one`, `two` * 2 AS `two`, `three`
# FROM my_data

# %%
proj = t[t]
print(ibis.impala.compile(proj))
# Out:
# SELECT *
# FROM my_data

# %%
proj = t[t, new_col]
print(ibis.impala.compile(proj))
# Out:
# SELECT *, `three` * 2 AS `new_col`
# FROM my_data

# %%
mutated = t.mutate(four=t.two * 2)
print(ibis.impala.compile(mutated))
# Out:
# SELECT *, `two` * 2 AS `four`
# FROM my_data

# %%
t2 = ibis.table(
    [('key', 'string'),
     ('value', 'double')], 'dim_table')

# %%
t2
# Out:
# UnboundTable[table]
#   name: dim_table
#   schema:
#     key : string
#     value : double

# %%
diff = (t.two - t2.value).name('diff')
joined = t.join(t2, t.one == t2.key)[t, diff]
joined
# Out:
# ref_0
# UnboundTable[table]
#   name: my_data
#   schema:
#     one : string
#     two : double
#     three : int32
#
# ref_1
# UnboundTable[table]
#   name: dim_table
#   schema:
#     key : string
#     value : double
#
# Selection[table]
#   table:
#     InnerJoin[table]
#       left:
#         Table: ref_0
#       right:
#         Table: ref_1
#       predicates:
#         Equals[boolean*]
#           left:
#             one = Column[string*] 'one' from table
#               ref_0
#           right:
#             key = Column[string*] 'key' from table
#               ref_1
#   selections:
#     Table: ref_0
#     diff = Subtract[double*]
#       left:
#         two = Column[double*] 'two' from table
#           ref_0
#       right:
#         value = Column[double*] 'value' from table
#           ref_1

# %%
print(ibis.postgres.compile(joined))
# Out:
# SELECT t0.one, t0.two, t0.three, t0.two - t1.value AS diff
# FROM my_data AS t0 JOIN dim_table AS t1 ON t0.one = t1.key

# %%
expr = (
    t.group_by(['one', 'three'])
        .aggregate(the_sum=t.two.sum())
        .group_by('one')
        .aggregate(mad=lambda x: x.the_sum.abs().mean())
)
expr
# Out:
# ref_0
# UnboundTable[table]
#   name: my_data
#   schema:
#     one : string
#     two : double
#     three : int32
#
# ref_1
# Aggregation[table]
#   table:
#     Table: ref_0
#   metrics:
#     the_sum = Sum[double]
#       two = Column[double*] 'two' from table
#         ref_0
#       where:
#         None
#   by:
#     one = Column[string*] 'one' from table
#       ref_0
#     three = Column[int32*] 'three' from table
#       ref_0
#
# Aggregation[table]
#   table:
#     Table: ref_1
#   metrics:
#     mad = Mean[double]
#       Abs[double*]
#         the_sum = Column[double*] 'the_sum' from table
#           ref_1
#       where:
#         None
#   by:
#     one = Column[string*] 'one' from table
#       ref_1

# %%
print(ibis.postgres.compile(expr))
# Out:
# SELECT t0.one, avg(abs(t0.the_sum)) AS mad
# FROM (SELECT t1.one AS one, t1.three AS three, sum(t1.two) AS the_sum
# FROM my_data AS t1 GROUP BY t1.one, t1.three) AS t0 GROUP BY t0.one

# %%
def mad(field):
    def closure(table):
        return table[field].abs().mean()
    return closure

# %%
expr = (
    t.group_by(['one', 'three'])
        .aggregate(the_sum=t.two.sum())
        .group_by('one')
        .aggregate(mad=mad('the_sum')))

# %%
filtered = t[t.two > 0][t.one]
print(ibis.impala.compile(filtered))
# Out:
# SELECT `one`
# FROM my_data
# WHERE `two` > 0

# %%
filtered = t.filter([
    t.two > 0,
    t.one.isin(['A', 'B'])
])
print(ibis.impala.compile(filtered))
# Out:
# SELECT *
# FROM my_data
# WHERE `two` > 0 AND
#       `one` IN ('A', 'B')

# %%
cond = (t.two < 0) | ((t.two > 0) & t.one.isin(['A', 'B']))
filtered = t[cond]
print(ibis.impala.compile(filtered))
# Out:
# SELECT *
# FROM my_data
# WHERE ((`two` < 0) OR ((`two` > 0) AND `one` IN ('A', 'B')))
